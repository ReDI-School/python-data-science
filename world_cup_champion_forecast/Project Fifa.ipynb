# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
% matplotlib inline

# %%
fifa = pd.read_csv('match_results.csv')

# %%
fifa.head(2)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
#
#     country  neutral
# 0  Scotland    False
# 1   England    False

# %%
fifa.shape
# Out:
# (38898, 9)

# %%
fifa.isnull().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
fifa.dtypes
# Out:
# date          object
# home_team     object
# away_team     object
# home_score     int64
# away_score     int64
# tournament    object
# city          object
# country       object
# neutral         bool
# dtype: object

# %%
fifa.head(5)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
fifa1 = fifa.iloc[:,[0,1,2,3,4]].copy()

# %%
fifa1.head(2)
# Out:
#          date home_team away_team  home_score  away_score
# 0  1872-11-30  Scotland   England           0           0
# 1  1873-03-08   England  Scotland           4           2

# %%
fifa1['date'] = pd.to_datetime(fifa1.date)

# %%
fifa1.dtypes
# Out:
# date          datetime64[ns]
# home_team             object
# away_team             object
# home_score             int64
# away_score             int64
# dtype: object

# %%
fifa1['date1'] = fifa1.date.dt.year

# %%
fifa1.head()
# Out:
#         date home_team away_team  home_score  away_score  date1
# 0 1872-11-30  Scotland   England           0           0   1872
# 1 1873-03-08   England  Scotland           4           2   1873
# 2 1874-03-07  Scotland   England           2           1   1874
# 3 1875-03-06   England  Scotland           2           2   1875
# 4 1876-03-04  Scotland   England           3           0   1876

# %%
fifa2 = fifa1[fifa1['date1'].isin([2010, 2014, 2018]) ].copy()

# %%
fifa2.head(2)
# Out:
#             date home_team  away_team  home_score  away_score  date1
# 31408 2010-01-02      Iran  Korea DPR           1           0   2010
# 31409 2010-01-02     Qatar       Mali           0           0   2010

# %%
fifa2.shape
# Out:
# (1823, 6)

# %%
fifa_stats = pd.read_csv('fifa_players_data.csv')

# %%
fifa_stats['year'] = ('20' + fifa_stats['year'].astype(str)).astype(int)

# %%
fifa_stats.head(2)
# Out:
#     age  country_code           dob     full_name  \
# 0  26.0             7  Jun 28, 1991  K. De Bruyne
# 1  26.0             7   Jan 7, 1991     E. Hazard
#
#                                              image   nation  potential  \
# 0  https://cdn.sofifa.org/1x/18/players/192985.png  Belgium       92.0
# 1  https://cdn.sofifa.org/1x/18/players/183277.png  Belgium       91.0
#
#    rating    short_name  value   wage  year
# 0    91.0  K. De Bruyne  104.5  395.0  2018
# 1    91.0     E. Hazard   95.5  405.0  2018

# %%
fifa_agg = fifa_stats.loc[:,['nation','rating',
                  'year'] ].groupby(['nation', 'year']).mean()

# %%
fifarank = pd.read_csv('fifa_rank.csv')

# %%
fifarank.head()
# Out:
#   Unnamed: 0  Value of Starting 11  Fifa Ranking
# 0     Russia                   855            66
# 1     Brazil                   933             2
# 2       Iran                   778            36
# 3      Japan                   839            60
# 4     Mexico                   863            15

# %%
fifa_agg.head(1)
# Out:
#               rating
# nation  year
# Albania 2010    72.0

# %%
fifa2.head(1)
# Out:
#             date home_team  away_team  home_score  away_score  date1  label
# 31408 2010-01-02      Iran  Korea DPR           1           0   2010      0

# %%
fifa2['label'] = 2

# %%
index_label0 = fifa2[fifa2['home_score'] > fifa2['away_score']].index

# %%
index_label1 = fifa2[fifa2['home_score'] < fifa2['away_score']].index

# %%
fifa2.loc[index_label0,'label'] = 0

# %%
fifa2.loc[index_label1,'label'] = 1

# %%
fifa2.head()
# Out:
#             date home_team   away_team  home_score  away_score  date1  label
# 31408 2010-01-02      Iran   Korea DPR           1           0   2010      0
# 31409 2010-01-02     Qatar        Mali           0           0   2010      2
# 31410 2010-01-02     Syria    Zimbabwe           6           0   2010      0
# 31411 2010-01-02     Yemen  Tajikistan           0           1   2010      1
# 31412 2010-01-03    Angola      Gambia           1           1   2010      2

# %%
fifa_reset = fifa_agg.reset_index()

# %%
fifarank=fifarank.rename(columns={'Unnamed: 0': "Team"})

# %%
fifarank.head()
# Out:
#      Team  Value of Starting 11  Fifa Ranking
# 0  Russia                   855            66
# 1  Brazil                   933             2
# 2    Iran                   778            36
# 3   Japan                   839            60
# 4  Mexico                   863            15

# %%
fifa_reset[fifa_reset['nation'].str.contains('Korea')]
# Out:
#             nation  year     rating
# 50  Korea Republic  2010  63.272727
# 51  Korea Republic  2014  73.181818
# 52  Korea Republic  2018  74.909091

# %%
fifa_reset['nation'].unique()
# Out:
# array(['Albania', 'Algeria', 'Argentina', 'Australia', 'Belgium',
#        'Bolivia', 'Brazil', 'Central African Rep.', 'Colombia',
#        'Costa Rica', 'Croatia', 'Denmark', 'Egypt', 'England',
#        'FYR Macedonia', 'France', 'Germany', 'Iceland', 'Iran', 'Japan',
#        'Korea Republic', 'Mexico', 'Morocco', 'Nigeria', 'Panama', 'Peru',
#        'Poland', 'Portugal', 'Russia', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Spain', 'Sweden', 'Switzerland', 'Tunisia', 'Uruguay',
#        'Venezuela'], dtype=object)

# %%
fifa_reset2 = fifa_reset.replace('Korea Republic', 'South Korea')

# %%
team_features=fifarank.merge(fifa_reset2, left_on="Team", right_on="nation", how='inner')
team_features['nation'].unique()
# Out:
# array(['Russia', 'Brazil', 'Iran', 'Japan', 'Mexico', 'Belgium',
#        'South Korea', 'Saudi Arabia', 'Germany', 'England', 'Spain',
#        'Nigeria', 'Costa Rica', 'Poland', 'Egypt', 'Iceland', 'Serbia',
#        'Portugal', 'France', 'Uruguay', 'Argentina', 'Colombia', 'Panama',
#        'Senegal', 'Morocco', 'Tunisia', 'Switzerland', 'Croatia',
#        'Sweden', 'Denmark', 'Australia', 'Peru'], dtype=object)

# %%
team_fer=team_features.loc[:,['Team', 'Fifa Ranking', 'year', 'rating']]

# %%
fifa3=fifa2.loc[:,['home_team', 'away_team', 'date1', 'label']]
fifa3.head()
# Out:
#       home_team   away_team  date1  label
# 31408      Iran   Korea DPR   2010      0
# 31409     Qatar        Mali   2010      2
# 31410     Syria    Zimbabwe   2010      0
# 31411     Yemen  Tajikistan   2010      1
# 31412    Angola      Gambia   2010      2

# %%
fifa4=fifa3.merge(team_fer, left_on=["home_team", "date1"], right_on=["Team", "year"], how='inner')

# %%
team_fer['Team'].unique().shape
# Out:
# (32,)

# %%
team_fer[team_fer.year == 2018].shape
# Out:
# (32, 4)

# %%
fifa3['home_team'].unique().shape
# Out:
# (205,)

# %%
fifa5=fifa4.rename(columns={'Fifa Ranking': "home_rank", 'rating': 'home_rating'})

# %%
fifa6=fifa5.merge(team_fer, left_on=["away_team", "date1"], right_on=["Team", "year"], how='inner')

# %%
fifa7=fifa6.rename(columns={'Fifa Ranking': "away_rank", 'rating': 'away_rating', 'date1': 'year'})
fifa7.head()
# Out:
#    home_team away_team  year  label     Team_x  home_rank  year_x  \
# 0       Iran    Brazil  2010      1       Iran         36    2010
# 1  Argentina    Brazil  2010      0  Argentina          5    2010
# 2   Portugal    Brazil  2010      2   Portugal          4    2010
# 3      Egypt   Nigeria  2010      0      Egypt         46    2010
# 4  Argentina   Nigeria  2010      0  Argentina          5    2010
#
#    home_rating   Team_y  away_rank  year_y  away_rating
# 0    71.400000   Brazil          2    2010    69.545455
# 1    69.600000   Brazil          2    2010    69.545455
# 2    69.818182   Brazil          2    2010    69.545455
# 3    65.888889  Nigeria         47    2010    63.909091
# 4    69.600000  Nigeria         47    2010    63.909091

# %%
fifa8=fifa7.loc[:,["year", "home_team", "away_team", "home_rank", "away_rank", "home_rating", "away_rating", "label"]]
fifa8.head()
# Out:
#    year  home_team away_team  home_rank  away_rank  home_rating  away_rating  \
# 0  2010       Iran    Brazil         36          2    71.400000    69.545455
# 1  2010  Argentina    Brazil          5          2    69.600000    69.545455
# 2  2010   Portugal    Brazil          4          2    69.818182    69.545455
# 3  2010      Egypt   Nigeria         46         47    65.888889    63.909091
# 4  2010  Argentina   Nigeria          5         47    69.600000    63.909091
#
#    label
# 0      1
# 1      0
# 2      2
# 3      0
# 4      0

# %%
fifa8["rank_dif"]=fifa8.home_rank-fifa8.away_rank
fifa8.head()
# Out:
#    year  home_team away_team  home_rank  away_rank  home_rating  away_rating  \
# 0  2010       Iran    Brazil         36          2    71.400000    69.545455
# 1  2010  Argentina    Brazil          5          2    69.600000    69.545455
# 2  2010   Portugal    Brazil          4          2    69.818182    69.545455
# 3  2010      Egypt   Nigeria         46         47    65.888889    63.909091
# 4  2010  Argentina   Nigeria          5         47    69.600000    63.909091
#
#    label  rank_dif
# 0      1        34
# 1      0         3
# 2      2         2
# 3      0        -1
# 4      0       -42

# %%
fifa8["rating_dif"]=fifa8.home_rating-fifa8.away_rating

# %%
fifa9=fifa8.loc[:,["year", "home_team", "away_team", "rank_dif", "rating_dif", "label"]]

# %%
fifa9
# Out:
#      year    home_team     away_team  rank_dif  rating_dif  label
# 0    2010         Iran        Brazil        34    1.854545      1
# 1    2010    Argentina        Brazil         3    0.054545      0
# 2    2010     Portugal        Brazil         2    0.272727      2
# 3    2010        Egypt       Nigeria        -1    1.979798      0
# 4    2010    Argentina       Nigeria       -42    5.690909      0
# 5    2010        Egypt     Australia        20    3.161616      0
